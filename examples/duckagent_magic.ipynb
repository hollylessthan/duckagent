# %%
# Load the magic (after installing the package)
# %load_ext duckagent.ipython_magic

# %%
import pandas as pd
df = pd.DataFrame({'country':['US','CA'], 'revenue':[100,200]})
# put df into the notebook namespace as `sales_df`
sales_df = df

# %%
# %%duckagent --df=sales_df --as_table=agent_result
# Summarize revenue by country
